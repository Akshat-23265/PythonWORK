# %%
s1 = 'Python'
s2 = "Data Science"
s3 = """Line1
Line2"""

print(s1)
print(s2)
print(s3)
# Out:
# Python
# Data Science
# Line1
# Line2

# %%
print("Py" + "thon")
print("ha" * 4)           
print("a" in "cat")    
print("abc" < "abd")
# Out:
# Python
# hahahaha
# True
# True

# %%
l =["Akshat", "Jain"]
"Jain" in l
# Out:
# True

# %%
s = "Akshat"
print(s[0])  
print(s[-1])  

print(s[len(s)-1])
# Out:
# A
# t
# t

# %%
s = "Python"
print(s[1:4])    
print(s[:3])     
print(s[3:])     
print(s[5:1:-1])
# Out:
# yth
# Pyt
# hon
# noht

# %%
print("one two three".split())
print("2026-02-10".split("-"))
# Out:
# ['one', 'two', 'three']
# ['2026', '02', '10']

# %%
L = [10, 20, 30]
mixed = [1, "A", 3.5, True]
empty = []
print(L)
print(mixed)
print(empty)
# Out:
# [10, 20, 30]
# [1, 'A', 3.5, True]
# []

# %%
L = [3, 1, 2]
L.append(5)    
print(L)
L.sort()          
print(L)
L.pop(2)
print(L)
L.remove(5)
print(L)
L.clear()
print(L)
# Out:
# [3, 1, 2, 5]
# [1, 2, 3, 5]
# [1, 2, 5]
# [1, 2]
# []

# %%
print([1,2] + [3,4])
print([0]*4)
print(2 in [1,2,3])
# Out:
# [1, 2, 3, 4]
# [0, 0, 0, 0]
# True

# %%
iterator = [1, 2, 3, 4]

squares = [item * item for item in iterator]
print(squares)
# Out:
# [1, 4, 9, 16]

# %%
squares = [x*x for x in range(1,6)]
evens = [x for x in range(10) if x%2==0]
pairs = [(x,y) for x in [1,2] for y in [3,4,6]]
print(squares)
print(evens)
print(pairs)
# Out:
# [1, 4, 9, 16, 25]
# [0, 2, 4, 6, 8]
# [(1, 3), (1, 4), (1, 6), (2, 3), (2, 4), (2, 6)]

# %%
mat = [[1,2,3],[4,5,6]]
print(mat[1][2])   # 6
# Out:
# 6

# %%
t1 = (1,2,3)
t2 = 1,2,3
t3 = (5,)

print(t1)
print(t2)
print(t3)
# Out:
# (1, 2, 3)
# (1, 2, 3)
# (5,)

# %%
t = (10,20,30,40)
print(t[1])
print(t[1:3])
# Out:
# 20
# (20, 30)

# %%
print((1,2,2,3).count(2))  
print((1,2,2,3).index(2))
# Out:
# 2
# 1

# %%
T = ((1,2),(3,4))
print(T[1][0])
# Out:
# 3

# %%
S = {1,2,3}
S2 = set([1,2,2,3])
empty_set = set()
print(S)
print(S2)
print(empty_set)
# Out:
# {1, 2, 3}
# {1, 2, 3}
# set()

# %%
A = {1,2,3}
B = {3,4,5}
print(A)
print(B)
print(A | B)
print(A & B)   
print(A - B)
# Out:
# {1, 2, 3}
# {3, 4, 5}
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}

# %%
d = {"name":"Akshat", "age":18}
d2 = dict(a=1, b=2)
print(d)
print(d2)
# Out:
# {'name': 'Akshat', 'age': 18}
# {'a': 1, 'b': 2}

# %%
print(d)
d["age"] = 18
print(d)
print(d.get("city", "NA"))
# Out:
# {'name': 'Akshat', 'age': 18}
# {'name': 'Akshat', 'age': 18}
# NA

# %%
student = {
  "name":"A",
  "marks":{"math":90, "python":95}
}
student["marks"]["python"]
# Out:
# 95

# %%
a="Alookichat"
sorted(a)
# Out:
# ['A', 'a', 'c', 'h', 'i', 'k', 'l', 'o', 'o', 't']

# %%
d = {"b":2, "a":5, "c":1}
print(sorted(d))
print(sorted(d.items()))
print(sorted(d.items(), key=lambda x: x[1]))
# Out:
# ['a', 'b', 'c']
# [('a', 5), ('b', 2), ('c', 1)]
# [('c', 1), ('b', 2), ('a', 5)]

# %%
def add(a, b):
    return a + b

# %%
def f(a, b=10):
    return a+b

def g(*args):
    return sum(args)

def h(**kwargs):
    return kwargs

# %%
def area_circle(r):
    """Return area of circle for radius r."""
    return 3.14159 * r * r

# %%
area_circle.__doc__
# Out:
# 'Return area of circle for radius r.'

# %%
sorted.__doc__
# Out:
# 'Return a new list containing all items from the iterable in ascending order.\n\nA custom key function can be supplied to customize the sort order, and the\nreverse flag can be set to request the result in descending order.'

# %%
x = 10
def foo():
    x = 5
    return x

# %%
x=10
print(foo())
print(x)
# Out:
# 5
# 10

# %%
def fact(n):
    if n == 0:
        return 1
    return n * fact(n - 1)

print(fact(4))
# Out:
# 24

# %%
def square(n):
    return n * n

print(square(2))
# Out:
# 4

# %%
def square(x):
    return x*x

# %%
l =[1,2,3,4]

# %%
def square(x):
    return x*x
new_list =[]
for each in l:
    new_list.append(square(each))

# %%
[x*x for x in l]
list(map(lambda x : x*x, l))
# Out:
# [1, 4, 9, 16]

# %%
def square(number):
    return number * number

numbers = [1, 2, 3, 4, 5]


squared_numbers = map(square, numbers)

print(list(squared_numbers))
# Out:
# [1, 4, 9, 16, 25]

# %%
list(map(square, l))
# Out:
# [1, 4, 9, 16]

# %%
nums = [1,2,3]
list(map(lambda x: 100/x, nums))
# Out:
# [100.0, 50.0, 33.333333333333336]

# %%
nums = [1,2,3,4,5]
list(filter(lambda x: x%2==0, nums))
# Out:
# [2, 4]

# %%
def outer(msg):
    def inner():
        return msg.upper()
    return inner

f = outer("hello")
print(f)
print(f())
# Out:
# <function outer.<locals>.inner at 0x0000021B8B49F2E0>
# HELLO

# %%
outer("bachaaoooo")()
# Out:
# 'BACHAAOOOO'

# %%
def apply_twice(f, x):
    return f(f(x))

apply_twice(lambda a: a+1, 5)
# Out:
# 7

# %%
def change_num(x):
    x = x + 1

def change_list(L):
    L.append(99)

a = 10
change_num(a)
print(a)

L = [1,2]
change_list(L)
print(L)
# Out:
# 10
# [1, 2, 99]
